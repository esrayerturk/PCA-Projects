# %%
import pandas as pd

# https://www.kaggle.com/fedesoriano/heart-failure-prediction
df = pd.read_csv("heart.csv")
df.head()
# Out:
#    Age Sex ChestPainType  RestingBP  ...  ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 0   40   M           ATA        140  ...               N      0.0       Up             0
# 1   49   F           NAP        160  ...               N      1.0     Flat             1
# 2   37   M           ATA        130  ...               N      0.0       Up             0
# 3   48   F           ASY        138  ...               Y      1.5     Flat             1
# 4   54   M           NAP        150  ...               N      0.0       Up             0
#
# [5 rows x 12 columns]

# %%
df.shape
# Out:
# (918, 12)

# %%
df.describe()
# Out:
#               Age   RestingBP  Cholesterol   FastingBS       MaxHR     Oldpeak  HeartDisease
# count  918.000000  918.000000   918.000000  918.000000  918.000000  918.000000    918.000000
# mean    53.510893  132.396514   198.799564    0.233115  136.809368    0.887364      0.553377
# std      9.432617   18.514154   109.384145    0.423046   25.460334    1.066570      0.497414
# min     28.000000    0.000000     0.000000    0.000000   60.000000   -2.600000      0.000000
# 25%     47.000000  120.000000   173.250000    0.000000  120.000000    0.000000      0.000000
# 50%     54.000000  130.000000   223.000000    0.000000  138.000000    0.600000      1.000000
# 75%     60.000000  140.000000   267.000000    0.000000  156.000000    1.500000      1.000000
# max     77.000000  200.000000   603.000000    1.000000  202.000000    6.200000      1.000000

# %%
df[df.Cholesterol>(df.Cholesterol.mean()+3*df.Cholesterol.std())]
# Out:
#      Age Sex ChestPainType  RestingBP  ...  ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 76    32   M           ASY        118  ...               N      0.0     Flat             1
# 149   54   M           ASY        130  ...               Y      1.0     Flat             1
# 616   67   F           NAP        115  ...               N      1.6     Flat             0
#
# [3 rows x 12 columns]

# %%
df.shape
# Out:
# (918, 12)

# %%
df1 = df[df.Cholesterol<=(df.Cholesterol.mean()+3*df.Cholesterol.std())]
df1.shape
# Out:
# (915, 12)

# %%
df[df.MaxHR>(df.MaxHR.mean()+3*df.MaxHR.std())]
# Out:
# Empty DataFrame
# Columns: [Age, Sex, ChestPainType, RestingBP, Cholesterol, FastingBS, RestingECG, MaxHR, ExerciseAngina, Oldpeak, ST_Slope, HeartDisease]
# Index: []

# %%
df[df.FastingBS>(df.FastingBS.mean()+3*df.FastingBS.std())]
# Out:
# Empty DataFrame
# Columns: [Age, Sex, ChestPainType, RestingBP, Cholesterol, FastingBS, RestingECG, MaxHR, ExerciseAngina, Oldpeak, ST_Slope, HeartDisease]
# Index: []

# %%
df[df.Oldpeak>(df.Oldpeak.mean()+3*df.Oldpeak.std())]
# Out:
#      Age Sex ChestPainType  RestingBP  ...  ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 166   50   M           ASY        140  ...               Y      5.0     Flat             1
# 702   59   M            TA        178  ...               N      4.2     Down             0
# 771   55   M           ASY        140  ...               Y      5.6     Down             1
# 791   51   M           ASY        140  ...               Y      4.2     Flat             1
# 850   62   F           ASY        160  ...               N      6.2     Down             1
# 900   58   M           ASY        114  ...               N      4.4     Down             1
#
# [6 rows x 12 columns]

# %%
df2 = df1[df1.Oldpeak<=(df1.Oldpeak.mean()+3*df1.Oldpeak.std())]
df2.shape
# Out:
# (909, 12)

# %%
df[df.RestingBP>(df.RestingBP.mean()+3*df.RestingBP.std())]
# Out:
#      Age Sex ChestPainType  RestingBP  ...  ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 109   39   M           ATA        190  ...               N      0.0       Up             0
# 241   54   M           ASY        200  ...               Y      2.0     Flat             1
# 365   64   F           ASY        200  ...               Y      1.0     Flat             1
# 399   61   M           NAP        200  ...               N      0.0     Flat             1
# 592   61   M           ASY        190  ...               Y      2.0     Down             1
# 732   56   F           ASY        200  ...               Y      4.0     Down             1
# 759   54   M           ATA        192  ...               N      0.0       Up             1
#
# [7 rows x 12 columns]

# %%
df3 = df2[df2.RestingBP<=(df2.RestingBP.mean()+3*df2.RestingBP.std())]
df3.shape
# Out:
# (902, 12)

# %%
df.ChestPainType.unique()
# Out:
# array(['ATA', 'NAP', 'ASY', 'TA'], dtype=object)

# %%
df.RestingECG.unique()
# Out:
# array(['Normal', 'ST', 'LVH'], dtype=object)

# %%
df.ExerciseAngina.unique()
# Out:
# array(['N', 'Y'], dtype=object)

# %%
df.ST_Slope.unique()
# Out:
# array(['Up', 'Flat', 'Down'], dtype=object)

# %%
df4 = df3.copy()
df4.ExerciseAngina.replace(
    {
        'N': 0,
        'Y': 1
    },
    inplace=True)

df4.ST_Slope.replace(
    {
        'Down': 1,
        'Flat': 2,
        'Up': 3
    },
    inplace=True
)

df4.RestingECG.replace(
    {
        'Normal': 1,
        'ST': 2,
        'LVH': 3
    },
    inplace=True)

df4.head()
# Out:
# <ipython-input-26-a955ffd5ad50>:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df4.ExerciseAngina.replace(
# <ipython-input-26-a955ffd5ad50>:2: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df4.ExerciseAngina.replace(
# <ipython-input-26-a955ffd5ad50>:9: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df4.ST_Slope.replace(
# <ipython-input-26-a955ffd5ad50>:9: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df4.ST_Slope.replace(
# <ipython-input-26-a955ffd5ad50>:18: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df4.RestingECG.replace(
# <ipython-input-26-a955ffd5ad50>:18: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df4.RestingECG.replace(
#    Age Sex ChestPainType  RestingBP  ...  ExerciseAngina  Oldpeak  ST_Slope  HeartDisease
# 0   40   M           ATA        140  ...               0      0.0         3             0
# 1   49   F           NAP        160  ...               0      1.0         2             1
# 2   37   M           ATA        130  ...               0      0.0         3             0
# 3   48   F           ASY        138  ...               1      1.5         2             1
# 4   54   M           NAP        150  ...               0      0.0         3             0
#
# [5 rows x 12 columns]

# %%
df5 = pd.get_dummies(df4, drop_first=True)
df5.head()
# Out:
#    Age  RestingBP  Cholesterol  ...  ChestPainType_ATA  ChestPainType_NAP  ChestPainType_TA
# 0   40        140          289  ...               True              False             False
# 1   49        160          180  ...              False               True             False
# 2   37        130          283  ...               True              False             False
# 3   48        138          214  ...              False              False             False
# 4   54        150          195  ...              False               True             False
#
# [5 rows x 14 columns]

# %%
X = df5.drop("HeartDisease",axis='columns')
y = df5.HeartDisease

X.head()
# Out:
#    Age  RestingBP  Cholesterol  ...  ChestPainType_ATA  ChestPainType_NAP  ChestPainType_TA
# 0   40        140          289  ...               True              False             False
# 1   49        160          180  ...              False               True             False
# 2   37        130          283  ...               True              False             False
# 3   48        138          214  ...              False              False             False
# 4   54        150          195  ...              False               True             False
#
# [5 rows x 13 columns]

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)
X_scaled
# Out:
# array([[-1.42896269,  0.46089071,  0.85238015, ...,  2.06757196,
#         -0.53547478, -0.22914788],
#        [-0.47545956,  1.5925728 , -0.16132855, ..., -0.4836591 ,
#          1.86750159, -0.22914788],
#        [-1.74679706, -0.10495034,  0.79657967, ...,  2.06757196,
#         -0.53547478, -0.22914788],
#        ...,
#        [ 0.37209878, -0.10495034, -0.61703246, ..., -0.4836591 ,
#         -0.53547478, -0.22914788],
#        [ 0.37209878, -0.10495034,  0.35947592, ...,  2.06757196,
#         -0.53547478, -0.22914788],
#        [-1.64085227,  0.3477225 , -0.20782894, ..., -0.4836591 ,
#          1.86750159, -0.22914788]])

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=30)

# %%
X_train.shape
# Out:
# (721, 13)

# %%
X_test.shape
# Out:
# (181, 13)

# %%
from sklearn.ensemble import RandomForestClassifier

model_rf = RandomForestClassifier()
model_rf.fit(X_train, y_train)
model_rf.score(X_test, y_test)
# Out:
# 0.8453038674033149

# %%
X
# Out:
#      Age  RestingBP  Cholesterol  ...  ChestPainType_ATA  ChestPainType_NAP  ChestPainType_TA
# 0     40        140          289  ...               True              False             False
# 1     49        160          180  ...              False               True             False
# 2     37        130          283  ...               True              False             False
# 3     48        138          214  ...              False              False             False
# 4     54        150          195  ...              False               True             False
# ..   ...        ...          ...  ...                ...                ...               ...
# 913   45        110          264  ...              False              False              True
# 914   68        144          193  ...              False              False             False
# 915   57        130          131  ...              False              False             False
# 916   57        130          236  ...               True              False             False
# 917   38        138          175  ...              False               True             False
#
# [902 rows x 13 columns]

# %%
from sklearn.decomposition import PCA

pca = PCA(0.95)
X_pca = pca.fit_transform(X)
X_pca
# Out:
# array([[ 93.82465373,  29.40099458],
#        [-15.58422331,  14.10909233],
#        [ 83.29606634, -38.6867453 ],
#        ...,
#        [-67.57318721, -17.61319354],
#        [ 40.70458237,  33.38750602],
#        [-19.91368346,  37.29085722]])

# %%
X_train_pca, X_test_pca, y_train, y_test = train_test_split(X_pca, y, test_size=0.2, random_state=30)

# %%
from sklearn.ensemble import RandomForestClassifier

model_rf = RandomForestClassifier()
model_rf.fit(X_train_pca, y_train)
model_rf.score(X_test_pca, y_test)
# Out:
# 0.7458563535911602
